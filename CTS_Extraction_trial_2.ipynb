# %% [markdown]
# Format Types
#
# 1) Plot Number **
#
# 2) Final Plot Number **
#
# 3) Kachara Number **
#
# 4) GAT NUMBER **
#
# 5) सि एस न **
#
# 6) Ward no **
#
# 7) Block Number  **
#
# 8) मध्दे आहे **
#
# 9) जुना

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel(r"/content/drive/MyDrive/data/final_byculla_v3.xlsx")
data.head()
# Out:
#    Unnamed: 0   Record ID                                 Land building info  \
# 0       66960  IGRMHDW4TN  पालिकेचे नाव:इतर वर्णन :सि एस नं 1840 पार्ट, स...
# 1       66964  IGRMUPFR2D  पालिकेचे नाव:इतर वर्णन :जमिन व बांधकाम , टेापी...
# 2       66981  IGRMX3ZMUO  पालिकेचे नाव:इतर वर्णन :डिलाईल रेाड क्रॉस लेन ...
# 3       67014  IGRM85KT4D  पालिकेचे नाव:इतर वर्णन :सि एस नं 1310, क्षेत्र...
# 4       67028  IGRMPZHVD6  पालिकेचे नाव:इतर वर्णन :सदनिका नं 501, 5 वा मज...
#
#                cts
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4  1971 मध्दे आहे.

# %%
data2 = data["cts"]

# %%
data2 = pd.DataFrame(data2)
data2['cts'] = data2['cts'].astype(str)

# %%
# trial-8 cts extraction:

import re

def remove_everything_from_character_to_end8(string: str) -> str:
  character = "मध्दे.*"

  regex = character + ".*"
  return re.sub(regex,"", string)

string = "1895 मध्दे आहे. -----सदनिका नं  15 -अे, 15 वा माळा, बेल्वेदर कोर्ट, साने गुरुजी मार्ग, महालक्ष्मी  मुं 11.-------2 कारपार्कींग सहीत नं  103 व 108,"
result = remove_everything_from_character_to_end8(string)
print(result)
# Out:
# 1895

# %%
data2["CTS8"] = data2['cts'].apply(remove_everything_from_character_to_end8)

data2 = data2.assign(final_cts=None)
data2['final_cts'] = data2['final_cts'].fillna(data2["CTS8"])

#print(data2)

# %%
# trial-7 cts extraction:

import re

def remove_everything_from_character_to_end7(string):
  character = "Block.*"

  regex = character + ".*"
  return re.sub(regex, "", string)

string = "222 Block Number."
result = remove_everything_from_character_to_end7(string)
print(result)
# Out:
# 222

# %%
data2["CTS7"] = data2['cts'].apply(remove_everything_from_character_to_end7)

data2['final_cts'] = data2['final_cts'].fillna(data2["CTS7"])

# %%
# trial-6 cts extraction:

import re

def remove_everything_from_character_to_end6(string):
  character = "Ward.*"

  regex = character + ".*"
  return re.sub(regex, "", string)

string = "222 Ward Number ifnjkwehukfhgfgfg."
result = remove_everything_from_character_to_end6(string)
print(result)
# Out:
# 222

# %%
data2["CTS6"] = data2['cts'].apply(remove_everything_from_character_to_end6)

data2['final_cts'] = data2['final_cts'].fillna(data2["CTS6"])

# %%
# trial-4 cts extraction:

import re

def remove_everything_from_character_to_end4(string):
  character = "GAT.*"

  regex = character + ".*"
  return re.sub(regex, "", string)

string = "222 GAT Number ifnjkwehukfhgfgfg."
result = remove_everything_from_character_to_end4(string)
print(result)
# Out:
# 222

# %%
data2["CTS4"] = data2['cts'].apply(remove_everything_from_character_to_end4)

data2['final_cts'] = data2['final_cts'].fillna(data2["CTS4"])

# %%
# trial-3 cts extraction:

import re

def remove_everything_from_character_to_end3(string):
  character = "Kachara.*"

  regex = character + ".*"
  return re.sub(regex, "", string)

string = "222 Kachara Number ifnjkwehukfhgfgfg."
result = remove_everything_from_character_to_end3(string)
print(result)
# Out:
# 222

# %%
data2["CTS3"] = data2['cts'].apply(remove_everything_from_character_to_end3)

data2['final_cts'] = data2['final_cts'].fillna(data2["CTS3"])

# %%
# trial-2 cts extraction:

import re

def remove_everything_from_character_to_end2(string):
  character = "Final.*"

  regex = character + ".*"
  return re.sub(regex, "", string)

string = "222 Final Number ifnjkwehukfhgfgfg."
result = remove_everything_from_character_to_end2(string)
print(result)
# Out:
# 222

# %%
data2["CTS2"] = data2['cts'].apply(remove_everything_from_character_to_end2)

data2['final_cts'] = data2['final_cts'].fillna(data2["CTS2"])

# %%
# trial-1 cts extraction:

import re

def remove_everything_from_character_to_end1(string):
  character = "Plot.*"

  regex = character + ".*"
  return re.sub(regex, "", string)

string = "214     Plot Number  602,610 ifnjkwehukfhgfgfg."
result = remove_everything_from_character_to_end1(string)
print(result)
# Out:
# 214

# %%
data2["CTS1"] = data2['cts'].apply(remove_everything_from_character_to_end1)

data2['final_cts'] = data2['final_cts'].fillna(data2["CTS1"])

# %%
#data2["CTS8"] = data2['cts'].apply(remove_everything_from_character_to_end8)
#data2["CTS7"] = data2['cts'].apply(remove_everything_from_character_to_end7)
#data2["CTS6"] = data2['cts'].apply(remove_everything_from_character_to_end6)
#data2["CTS4"] = data2['cts'].apply(remove_everything_from_character_to_end4)
#data2["CTS3"] = data2['cts'].apply(remove_everything_from_character_to_end3)
#data2["CTS2"] = data2['cts'].apply(remove_everything_from_character_to_end2)
#data2["CTS1"] = data2['cts'].apply(remove_everything_from_character_to_end1)

# %%
#data2 = data2.assign(final_cts=None)
#data2['final_cts'] = data2['final_cts'].fillna(data2["CTS8"])
#data2['final_cts'] = data2['final_cts'].fillna(data2["CTS7"])
#data2['final_cts'] = data2['final_cts'].fillna(data2["CTS6"])
#data2['final_cts'] = data2['final_cts'].fillna(data2["CTS4"])
#data2['final_cts'] = data2['final_cts'].fillna(data2["CTS3"])
#data2['final_cts'] = data2['final_cts'].fillna(data2["CTS2"])
#data2['final_cts'] = data2['final_cts'].fillna(data2["CTS1"])
data2['final_cts'] = data2['final_cts'].fillna(data2["cts"])

# %%
data2
# Out:
#                 cts   CTS8 final_cts             CTS7             CTS6  \
# 0               nan    nan       nan              nan              nan
# 1               nan    nan       nan              nan              nan
# 2               nan    nan       nan              nan              nan
# 3               nan    nan       nan              nan              nan
# 4   1971 मध्दे आहे.  1971      1971   1971 मध्दे आहे.  1971 मध्दे आहे.
# ..              ...    ...       ...              ...              ...
# 95              nan    nan       nan              nan              nan
# 96  1560 मध्दे आहे.  1560      1560   1560 मध्दे आहे.  1560 मध्दे आहे.
# 97              nan    nan       nan              nan              nan
# 98              nan    nan       nan              nan              nan
# 99              nan    nan       nan              nan              nan
#
#                CTS4             CTS3             CTS2             CTS1
# 0               nan              nan              nan              nan
# 1               nan              nan              nan              nan
# 2               nan              nan              nan              nan
# 3               nan              nan              nan              nan
# 4   1971 मध्दे आहे.  1971 मध्दे आहे.  1971 मध्दे आहे.  1971 मध्दे आहे.
# ..              ...              ...              ...              ...
# 95              nan              nan              nan              nan
# 96  1560 मध्दे आहे.  1560 मध्दे आहे.  1560 मध्दे आहे.  1560 मध्दे आहे.
# 97              nan              nan              nan              nan
# 98              nan              nan              nan              nan
# 99              nan              nan              nan              nan
#
# [100 rows x 9 columns]

# %%
data3 = data2 ['final_cts']
data3 = pd.DataFrame(data3)
data3['final_cts'] = data3['final_cts'].fillna("")
#data2 = data2.assign(final_cts=None)
data3 = data3.assign(cts=None)
data3['cts'] = data['cts']
#print(data3)

# %%
from google.colab import files
# Export the DataFrame to Excel
with open('final.xlsx', 'wb') as f:
    data3.to_excel(f, index=False)

# Download the Excel file
files.download('final.xlsx')
